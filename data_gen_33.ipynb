# %% [markdown]
# <a href="https://colab.research.google.com/github/BasilPy/Eng_uk_ru_patterns/blob/main/data_gen_33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### Connect to Gdrive, import modules, change directory and load csv as a dataframe
from google.colab import drive
drive.mount('/content/gdrive')
import pandas as pd
# !pip install googletrans==3.1.0a0
import googletrans
from googletrans import Translator
# %cd ./gdrive/MyDrive/csv_gen_eng_patterns/
df = pd.read_csv('df_33_ukr_srp_rus.csv')
### English verbs dataset was taken from https://www.wordexample.com/list/most-common-verbs-english
# Out:
# Mounted at /content/gdrive
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2023.7.22)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2023.1.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 25.3 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.0)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 15.5 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.6 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.4 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.1 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.3 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16352 sha256=351141c675424ac607329589ef590e16668d3c225781ed17167997f6999eea22
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.4
#     Uninstalling idna-3.4:
#       Successfully uninstalled idna-3.4
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2023.1.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0
# /content/gdrive/MyDrive/csv_gen_eng_patterns

# %%
### one of the function of how I created the columns:
def g_tr_she_uk(data: str):
  data_tmp=f'she {data}'
  #print(data)
  tmp = translator.translate(data_tmp, src='en', dest='uk').text
  print(tmp)
  try:
    return tmp.split(' ')[1]
  except:
    return tmp.split(' ')[0]

df['uk_3s'] = df['Word'].apply(g_tr_she_uk)
# enother way, but it may have problems with tranclation as a noun or with ending of verb
#df['Word_uk'] = df['Word'].apply(lambda x: translator.translate(x, src='en', dest='uk').text)

# %%
### Serbian/Montenegrin/Croatian
translator = Translator()
def g_tr_srp(data: str):
  data_tmp=f'{data}'
  print(data)
  tmp = translator.translate(data_tmp, src='en', dest='hr').text
  print(tmp)
  try:
    return tmp.split(' ')[1]
  except:
    return tmp.split(' ')[0]

df['Word_srp'] = df['Word'].apply(g_tr_srp)
# Out:
# have
# imati
# do
# čini
# know
# znati
# see
# vidjeti
# get
# dobiti
# think
# razmišljati
# go
# ići
# make
# napraviti
# take
# uzeti
# come
# doći
# say
# reći
# put
# staviti
# want
# željeti
# give
# dati
# look
# izgled
# find
# pronaći
# need
# potreba
# like
# Kao
# set
# postaviti
# use
# koristiti
# become
# postati
# tell
# reći
# keep
# zadržati
# help
# Pomozite
# work
# raditi
# let
# neka
# feel
# osjetiti
# provide
# pružiti
# believe
# vjerovati
# try
# probati
# ask
# pitati
# remember
# zapamtiti
# leave
# napustiti

# %%
df.iloc[0:33]
# Out:
#         Word  3singular Present Participle Simple Past Past Participle  \
# 0       have        has             having         had             had
# 1         do       does              doing         did            done
# 2       know      knows            knowing        knew           known
# 3        see       sees             seeing         saw            seen
# 4        get       gets            getting         got             got
# 5      think     thinks           thinking     thought         thought
# 6         go       goes              going        went            gone
# 7       make      makes             making        made            made
# 8       take      takes             taking        took           taken
# 9       come      comes             coming        came            come
# 10       say       says             saying        said            said
# 11       put       puts            putting         put             put
# 12      want      wants            wanting      wanted          wanted
# 13      give      gives             giving        gave           given
# 14      look      looks            looking      looked          looked
# 15      find      finds            finding       found           found
# 16      need      needs            needing      needed          needed
# 17      like      likes             liking       liked           liked
# 18       set       sets            setting         set             set
# 19       use       uses              using        used            used
# 20    become    becomes           becoming      became          become
# 21      tell      tells            telling        told            told
# 22      keep      keeps            keeping        kept            kept
# 23      help      helps            helping      helped          helped
# 24      work      works            working      worked          worked
# 25       let       lets            letting         let             let
# 26      feel      feels            feeling        felt            felt
# 27   provide   provides          providing    provided        provided
# 28   believe   believes          believing    believed        believed
# 29       try      tries             trying       tried           tried
# 30       ask       asks             asking       asked           asked
# 31  remember  remembers        remembering  remembered      remembered
# 32     leave     leaves            leaving        left            left
#
#             Word_uk        Word_ru          ru_I        ru_they  \
# 0              мати          иметь          имею          имеют
# 1            робити         делать         делаю         делают
# 2             знати          знать          знаю          знают
# 3          побачити         видеть          вижу          видят
# 4          отримати       получать       получаю       получают
# 5            думати         думать         думаю         думают
# 6            думати           идти           иду           идут
# 7           зробити         делать         делаю         делают
# 8             брати          брать          беру          берут
# 9         приходити      приходить       прихожу       приходят
# 10           казати        сказать        говорю        говорят
# 11           класти         класть         кладу         кладут
# 12           хотіти         хотеть          хочу          хотят
# 13           давати         давать           даю           дают
# 14         дивитися       смотреть        смотрю        смотрят
# 15        знаходити       находить        нахожу        находят
# 16      потребувати      нуждаться      нуждаюсь      нуждаются
# 17      подобається      нравиться      нравится       нравится
# 18       встановити  устанавливать  устанавливаю  устанавливают
# 19  використовувати   использовать     использую     используют
# 20            стати    становиться    становлюсь     становятся
# 21      розповідати   рассказывать   рассказываю   рассказывают
# 22          тримати        держать         держу         держат
# 23       допомагати       помогать       помогаю       помогают
# 24        працювати       работать       работаю       работают
# 25        дозволяти      позволять      позволяю      позволяют
# 26        відчувати    чувствовать      чувствую      чувствуют
# 27      забезпечити   обеспечивать   обеспечиваю   обеспечивают
# 28           вірити         верить          верю          верят
# 29       намагатися       пытаться       пытаюсь       пытаются
# 30       запитувати     спрашивать     спрашиваю     спрашивают
# 31      запам'ятати        помнить         помню         помнят
# 32         залишати      оставлять      оставляю       оставляю
#
#             ru_we  ...       uk_you_vu      uk_you_tu         uk_3s  \
# 0           имеем  ...           маєте           маєш           має
# 1          делаем  ...          робите          робиш        робить
# 2           знаем  ...          знаєте          знаєш          знає
# 3           видим  ...          бачите          бачиш        бачить
# 4        получаем  ...       отримуєте       отримуєш       отримує
# 5          думаем  ...         думаєте         думаєш         думає
# 6            идем  ...           йдете           йдеш           йде
# 7          делаем  ...          робите          робиш        робить
# 8           берем  ...          берете          береш          бере
# 9        приходим  ...       приходите       приходиш     приходить
# 10        говорим  ...          кажете          кажеш          каже
# 11         кладем  ...         кладете         кладеш         кладе
# 12          хотим  ...          хочете          хочеш          хоче
# 13           даем  ...           даєте           даєш           дає
# 14        смотрим  ...        дивитеся        дивишся      дивиться
# 15        находим  ...       знаходите       знаходиш     знаходить
# 16      нуждаемся  ...      потребуєте      потребуєш      потребує
# 17       нравится  ...     подобається    подобається   подобається
# 18  устанавливаем  ...    встановлюєте    встановлюєш    встановлює
# 19     используем  ...  використовуєте  використовуєш  використовує
# 20     становимся  ...          стаєте          стаєш          стає
# 21   рассказываем  ...    розповідаєте    розповідаєш    розповідає
# 22         держим  ...        тримаєте        тримаєш        тримає
# 23       помогаем  ...     допомагаєте     допомагаєш     допомагає
# 24       работаем  ...        працюєте        працюєш        працює
# 25      позволяем  ...      дозволяєте      дозволяєш      дозволяє
# 26      чувствуем  ...      відчуваєте      відчуваєш      відчуває
# 27   обеспечиваем  ...    забезпечуєте    забезпечуєш    забезпечує
# 28          верим  ...          вірите          віриш        вірить
# 29       пытаемся  ...     намагаєтеся     намагаєшся   намагається
# 30     спрашиваем  ...         питаєте         питаєш       запитує
# 31         помним  ...       пам'ятаєш      пам'ятаєш      пам'ятає
# 32      оставляем  ...       залишаєте       залишаєш       залишає
#
#         srp_I    srp_they         srp_we       srp_tu    srp_vu    srp_3s  \
# 0        imam       imaju          imamo         imaš     imate       ima
# 1        znam        čine         radimo        radiš    radite      radi
# 2        Znam       znaju          znamo         znaš     znate       zna
# 3       vidim        vide         vidimo        vidiš    vidite      vidi
# 4     dobivam      dobiju       dobivamo      dobivaš  dobivate    dobiti
# 5      mislim       misle        mislimo       misliš   mislite     misli
# 6        idem         idu          idemo         ideš     idete       ide
# 7      pravim       prave        pravimo        radis     radiš   napravi
# 8      uzimam     uzimaju        uzimamo       uzmete    uzmete     uzeti
# 9     dolazim      dolaze       dolazimo      dolaziš  dolazite    dolazi
# 10      kažem        kažu         kažemo        kažeš     kažeš      kaže
# 11        sam          su      stavljamo        stavi     stavi        je
# 12      Želim        žele         želimo        želiš     želiš      želi
# 13      dajem        daju         dajemo        daješ     daješ      dati
# 14   izgledam     gledaju        gledamo       gledaš  izgledaš   izgleda
# 15    nalazim      nalaze            smo      Pronađi   Pronađi   pronaći
# 16     trebam          im        trebamo       trebaš    trebaš     treba
# 17      volim        vole         volimo           li        se      voli
# 18        sam          su            smo  instalirate        si        je
# 19   koristim     koriste      koristimo     koristiš  koristiš   koristi
# 20   postajem          su      postajemo     postajes  postajes   postati
# 21      Kažem      govore         kažemo         reci      reci      reći
# 22      držim      čuvaju         čuvamo        držiš     čuvaš  zadržati
# 23    pomažem      pomažu       pomažemo      pomažeš   pomažeš     pomoć
# 24      radim        rade         radimo           li     radiš      radi
# 25     puštam   dopuštaju      dopuštamo    dopuštate  dopustiš        je
# 26    osjećam    osjećaju       osjećamo     osjećate  osjećate    osjeća
# 27     pružam     pružaju  opskrbljujemo      pružate   pružate   pružiti
# 28   vjerujem     vjeruju      vjerujemo           li  vjeruješ   vjeruje
# 29  pokušavam  pokušavaju     pokušavamo           li    probaj  pokušati
# 30      pitam      pitaju         pitamo        pitaš     pitaš       ona
# 31         se          se             se           li        se        se
# 32    odlazim      odlaze       Odlazimo      odlaziš   odlaziš    odlazi
#
#        Word_srp
# 0         imati
# 1          čini
# 2         znati
# 3       vidjeti
# 4        dobiti
# 5   razmišljati
# 6           ići
# 7     napraviti
# 8         uzeti
# 9          doći
# 10         reći
# 11      staviti
# 12      željeti
# 13         dati
# 14       izgled
# 15      pronaći
# 16      potreba
# 17          Kao
# 18    postaviti
# 19    koristiti
# 20      postati
# 21         reći
# 22     zadržati
# 23     Pomozite
# 24       raditi
# 25         neka
# 26     osjetiti
# 27      pružiti
# 28    vjerovati
# 29      probati
# 30       pitati
# 31    zapamtiti
# 32    napustiti
#
# [33 rows x 26 columns]

# %%
df.loc[7, 'srp_vu'] = "idete"
df.loc[7, 'srp_tu'] = "ideš" #pravite
